# %% [markdown]
# # Minecraft server
#
# - erstelle mit java -jar BuildTools.jar
# - cp spiegot.jar server/spiegot.jar
# - starte mit java -jar -Xmx2048M spigot.jar

# %%
cd /tmp
mkdir -p minecraft/server
cd minecraft

# %%
wget https://hub.spigotmc.org/jenkins/job/BuildTools/71/artifact/target/BuildTools.jar
# Out:
# --2018-03-13 17:08:37--  https://hub.spigotmc.org/jenkins/job/BuildTools/71/artifact/target/BuildTools.jar
# Auflösen des Hostnamen »hub.spigotmc.org (hub.spigotmc.org)«... 104.27.200.92, 104.27.201.92, 2400:cb00:2048:1::681b:c95c, ...
# Verbindungsaufbau zu hub.spigotmc.org (hub.spigotmc.org)|104.27.200.92|:443... verbunden.
# HTTP-Anforderung gesendet, warte auf Antwort... 200 OK
# Länge: 3965192 (3,8M) [application/java-archive]
# In »»BuildTools.jar«« speichern.
#
# BuildTools.jar      100%[===================>]   3,78M  1,40MB/s    in 2,7s
#
# 2018-03-13 17:08:41 (1,40 MB/s) - »BuildTools.jar« gespeichert [3965192/3965192]

# %%
cd /home/wipf/minecraft
java -jar BuildTools.jar
# Out:
# Loading BuildTools version: git-BuildTools-3346dd9-71 (#71)
# git version 2.7.4
# BuildTools
# unconfigured@null.spigotmc.org
# Attempting to build version: 'latest' use --rev <version> to override
# Found version
# {
# 	"name": "1534",
# 	"description": "Jenkins build 1534",
# 	"refs": {
# 		"BuildData": "a9c4523879abc011821f06283dd468c67c3b0097",
# 		"Bukkit": "02f0647216dfe7515e3d7fa75a618faf6f010a7c",
# 		"CraftBukkit": "7e94e65a1ca93e86dbc2eed3cca77c8a9ed8c102",
# 		"Spigot": "c3093efafc5eab1ea62a8a57aa47f28f5ea85d03"
# 	},
# 	"toolsVersion": 47
# }
#
# Pulling updates for /home/wipf/minecraft/BuildData/.git
# Successfully fetched updates!
# Checked out: a9c4523879abc011821f06283dd468c67c3b0097
# Pulling updates for /home/wipf/minecraft/Bukkit/.git
# Successfully fetched updates!
# Checked out: 02f0647216dfe7515e3d7fa75a618faf6f010a7c
# Pulling updates for /home/wipf/minecraft/CraftBukkit/.git
# Successfully fetched updates!
# Checked out: 7e94e65a1ca93e86dbc2eed3cca77c8a9ed8c102
# Pulling updates for /home/wipf/minecraft/Spigot/.git
# Successfully fetched updates!
# Checked out: c3093efafc5eab1ea62a8a57aa47f28f5ea85d03
# Attempting to build Minecraft with details: VersionInfo(minecraftVersion=1.12.2, accessTransforms=bukkit-1.12.2.at, classMappings=bukkit-1.12.2-cl.csrg, memberMappings=bukkit-1.12.2-members.csrg, packageMappings=package.srg, minecraftHash=71728ed3fbd0acd1394bf3ade2649a5c, decompileCommand=java -jar BuildData/bin/fernflower.jar -dgs=1 -hdc=0 -asc=1 -udv=0 {0} {1}, serverUrl=https://launcher.mojang.com/mc/game/1.12.2/server/886945bfb2b978778c3a0288fd7fab09d315b25f/server.jar)
# Found good Minecraft hash (71728ed3fbd0acd1394bf3ade2649a5c)
# Found good Minecraft hash (71728ed3fbd0acd1394bf3ade2649a5c)
# [INFO] Scanning for projects...
# [INFO]
# [INFO] ------------------------------------------------------------------------
# [INFO] Building Maven Stub Project (No POM) 1
# [INFO] ------------------------------------------------------------------------
# [INFO]
# [INFO] --- maven-install-plugin:2.4:install-file (default-cli) @ standalone-pom ---
# [INFO] Installing /home/wipf/minecraft/work/mapped.cf6b1333.jar to /home/wipf/.m2/repository/org/spigotmc/minecraft-server/1.12.2-SNAPSHOT/minecraft-server-1.12.2-SNAPSHOT.jar
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time: 0.804 s
# [INFO] Finished at: 2018-03-13T16:37:40+01:00
# [INFO] Final Memory: 6M/106M
# [INFO] ------------------------------------------------------------------------
# Applying CraftBukkit Patches
# Backing up NMS dir
# Patching with Advancements.patch
# Patching with TileEntity.patch
# Patching with RemoteControlCommandListener.patch
# Patching with EntityEnderman.patch
# Patching with BlockWaterLily.patch
# Patching with BlockLeaves.patch
# Patching with BlockConcretePowder.patch
# Patching with DataInspectorBlockEntity.patch
# Patching with EntityParrot.patch
# Patching with ItemBoat.patch
# Patching with EntityLlamaSpit.patch
# Patching with WorldBorder.patch
# Patching with ContainerWorkbench.patch
# Patching with EntityItem.patch
# Patching with BlockStationary.patch
# Patching with ContainerBrewingStand.patch
# Patching with ItemMinecart.patch
# Patching with BlockChorusFlower.patch
# Patching with RecipeTippedArrow.patch
# Patching with PathfinderGoalOwnerHurtTarget.patch
# Patching with PlayerInventory.patch
# Patching with EntityMinecartCommandBlock.patch
# Patching with EntityAnimal.patch
# Patching with EntityArmorStand.patch
# Patching with WorldData.patch
# Patching with BlockPortal.patch
# Patching with CustomFunction.patch
# Patching with InventoryLargeChest.patch
# Patching with EntityWitherSkull.patch
# Patching with AdvancementDataPlayer.patch
# Patching with SecondaryWorldServer.patch
# Patching with EntityShulker.patch
# Patching with ChatModifier.patch
# Patching with ChunkProviderGenerate.patch
# Patching with EntityVex.patch
# Patching with BlockMushroom.patch
# Patching with Chunk.patch
# Patching with ContainerHorse.patch
# Patching with ChunkRegionLoader.patch
# Patching with CommandTp.patch
# Patching with WorldGenGroundBush.patch
# Patching with EntityEgg.patch
# Patching with ItemBow.patch
# Patching with PlayerChunk.patch
# Patching with EntityZombieVillager.patch
# Patching with TileEntityDispenser.patch
# Patching with RecipeBookClone.patch
# Patching with PacketPlayInCloseWindow.patch
# Patching with CommandBlockListenerAbstract.patch
# Patching with TileEntityChest.patch
# Patching with World.patch
# Patching with EntityLightning.patch
# Patching with EntityMushroomCow.patch
# Patching with DamageSource.patch
# Patching with InventoryHorseChest.patch
# Patching with EntityThrownExpBottle.patch
# Patching with EnchantmentFrostWalker.patch
# Patching with ContainerPlayer.patch
# Patching with TileEntityContainer.patch
# Patching with BlockDoor.patch
# Patching with VillageSiege.patch
# Patching with BlockSkull.patch
# Patching with ItemRedstone.patch
# Patching with EntitySlime.patch
# Patching with AdvancementRewards.patch
# Patching with Village.patch
# Patching with IDataManager.patch
# Patching with EntityPainting.patch
# Patching with BlockSnowBlock.patch
# Patching with EntityEnderDragon.patch
# Patching with PathfinderGoalSit.patch
# Patching with EntityDamageSourceIndirect.patch
# Patching with BlockFlowing.patch
# Patching with BlockPiston.patch
# Patching with TileEntityShulkerBox.patch
# Patching with MethodProfiler.patch
# Patching with BlockButtonAbstract.patch
# Patching with DragonControllerManager.patch
# Patching with BlockRedstoneTorch.patch
# Patching with EntitySilverfish.patch
# Patching with RecipeArmorDye.patch
# Patching with MinecraftServer.patch
# Patching with ItemWorldMap.patch
# Patching with BlockPoweredRail.patch
# Patching with CrashReport.patch
# Patching with BlockTripwire.patch
# Patching with EntityAgeable.patch
# Patching with BlockCommand.patch
# Patching with RecipeShulkerBox.patch
# Patching with EntityLeash.patch
# Patching with ItemMonsterEgg.patch
# Patching with PathfinderGoalTempt.patch
# Patching with ItemSnowball.patch
# Patching with Advancement.patch
# Patching with CommandSpreadPlayers.patch
# Patching with BlockMonsterEggs.patch
# Patching with ScoreboardServer.patch
# Patching with BlockCrops.patch
# Patching with BlockMagma.patch
# Patching with ContainerAnvil.patch
# Patching with BlockRedstoneWire.patch
# Patching with WorldGenVillagePieces.patch
# Patching with BlockFire.patch
# Patching with EntityHanging.patch
# Patching with ItemHanging.patch
# Patching with ItemRecord.patch
# Patching with EntityZombie.patch
# Patching with PropertyManager.patch
# Patching with TileEntityStructure.patch
# Patching with PathfinderGoalBreakDoor.patch
# Patching with BlockTrapdoor.patch
# Patching with PathfinderGoalNearestAttackableTarget.patch
# Patching with WorldGenRegistration.patch
# Patching with BlockDaylightDetector.patch
# Patching with EntityFireball.patch
# Patching with BlockSapling.patch
# Patching with BlockDragonEgg.patch
# Patching with ContainerShulkerBox.patch
# Patching with EntityTippedArrow.patch
# Patching with NameReferencingFileConverter.patch
# Patching with UserCache.patch
# Patching with PlayerChunkMap.patch
# Patching with DataPaletteBlock.patch
# Patching with EntityLargeFireball.patch
# Patching with BlockSoil.patch
# Patching with InventorySubcontainer.patch
# Patching with NetworkManager.patch
# Patching with WorldProviderHell.patch
# Patching with BlockPlant.patch
# Patching with TileEntityBeacon.patch
# Patching with BlockJukeBox.patch
# Patching with PathfinderGoalMakeLove.patch
# Patching with DispenseBehaviorProjectile.patch
# Patching with PathfinderGoalHorseTrap.patch
# Patching with InventoryEnderChest.patch
# Patching with EntityIronGolem.patch
# Patching with SpawnerCreature.patch
# Patching with EntityPlayer.patch
# Patching with EntitySlice.patch
# Patching with WorldManager.patch
# Patching with RecipiesShield.patch
# Patching with BlockReed.patch
# Patching with InventoryCrafting.patch
# Patching with BlockTripwireHook.patch
# Patching with BlockLever.patch
# Patching with BlockMycel.patch
# Patching with ItemBlock.patch
# Patching with PacketStatusListener.patch
# Patching with HandshakeListener.patch
# Patching with ContainerDispenser.patch
# Patching with EntityTracker.patch
# Patching with EntityItemFrame.patch
# Patching with ContainerEnchantTable.patch
# Patching with EntityMinecartContainer.patch
# Patching with WorldMap.patch
# Patching with EntitySmallFireball.patch
# Patching with BlockGrass.patch
# Patching with TileEntityBanner.patch
# Patching with EntityMonster.patch
# Patching with EntityWither.patch
# Patching with BlockMinecartDetector.patch
# Patching with EntityProjectile.patch
# Patching with ContainerHopper.patch
# Patching with ItemWaterLily.patch
# Patching with ContainerBeacon.patch
# Patching with ContainerMerchant.patch
# Patching with BlockEnderPortal.patch
# Patching with EntityHorseAbstract.patch
# Patching with ItemReed.patch
# Patching with ChunkSection.patch
# Patching with PathfinderGoalDefendVillage.patch
# Patching with CommandTeleport.patch
# Patching with EntityFishingHook.patch
# Patching with EnchantmentThorns.patch
# Patching with PathfinderGoalPanic.patch
# Patching with RecipesBanner.patch
# Patching with EntityFallingBlock.patch
# Patching with EntityTNTPrimed.patch
# Patching with Entity.patch
# Patching with Block.patch
# Patching with WorldGenMegaTreeAbstract.patch
# Patching with ContainerChest.patch
# Patching with ItemBucket.patch
# Patching with CommandGamemode.patch
# Patching with EntityChicken.patch
# Patching with DedicatedServer.patch
# Patching with ExpirableListEntry.patch
# Patching with EntityCreature.patch
# Patching with InventoryMerchant.patch
# Patching with BlockDiodeAbstract.patch
# Patching with RecipeRepair.patch
# Patching with BlockStem.patch
# Patching with BlockTallPlant.patch
# Patching with BlockShulkerBox.patch
# Patching with BlockCocoa.patch
# Patching with PacketPlayOutWorldBorder.patch
# Patching with EntityCreeper.patch
# Patching with EntityBoat.patch
# Patching with BlockPressurePlateWeighted.patch
# Patching with Explosion.patch
# Patching with RecipeMapClone.patch
# Patching with EntityHorseChestedAbstract.patch
# Patching with ItemFlintAndSteel.patch
# Patching with EntityTrackerEntry.patch
# Patching with ItemFireball.patch
# Patching with MobSpawnerAbstract.patch
# Patching with ItemLeash.patch
# Patching with ChunkProviderServer.patch
# Patching with MobEffectList.patch
# Patching with FoodMetaData.patch
# Patching with BlockMobSpawner.patch
# Patching with BlockRedstoneLamp.patch
# Patching with ChatBaseComponent.patch
# Patching with PathfinderGoalVillagerFarm.patch
# Patching with ShapelessRecipes.patch
# Patching with EntityPotion.patch
# Patching with EntityHuman.patch
# Patching with BlockPressurePlateBinary.patch
# Patching with WorldNBTStorage.patch
# Patching with TileEntityCommand.patch
# Patching with CommandGamerule.patch
# Patching with ItemArmor.patch
# Patching with EntitySheep.patch
# Patching with BlockDispenser.patch
# Patching with CommandDebug.patch
# Patching with ItemSkull.patch
# Patching with EntityVillager.patch
# Patching with Container.patch
# Patching with EntityPig.patch
# Patching with EntitySnowman.patch
# Patching with PlayerInteractManager.patch
# Patching with BlockTNT.patch
# Patching with EntitySpider.patch
# Patching with EntityCow.patch
# Patching with BlockNetherWart.patch
# Patching with JsonList.patch
# Patching with LoginListener.patch
# Patching with RegionFileCache.patch
# Patching with EntityRabbit.patch
# Patching with PathfinderGoalOwnerHurtByTarget.patch
# Patching with ItemFishingRod.patch
# Patching with BlockPumpkin.patch
# Patching with TileEntityNote.patch
# Patching with PathfinderGoalTargetNearestPlayer.patch
# Patching with EntityWolf.patch
# Patching with PathfinderGoalEatTile.patch
# Patching with TileEntitySign.patch
# Patching with DataWatcher.patch
# Patching with StatisticManager.patch
# Patching with ItemEnderPearl.patch
# Patching with EntityOcelot.patch
# Patching with BlockSnow.patch
# Patching with BlockFluids.patch
# Patching with Enchantment.patch
# Patching with TileEntityFurnace.patch
# Patching with BlockPressurePlateAbstract.patch
# Patching with BlockRedstoneOre.patch
# Patching with DispenseBehaviorItem.patch
# Patching with PlayerList.patch
# Patching with PathfinderGoalBreed.patch
# Patching with CraftingManager.patch
# Patching with PathfinderGoalTarget.patch
# Patching with BlockOre.patch
# Patching with MerchantRecipe.patch
# Patching with CustomFunctionData.patch
# Patching with RecipesFurnace.patch
# Patching with ShapedRecipes.patch
# Patching with ItemDye.patch
# Patching with BlockIce.patch
# Patching with EntitySkeleton.patch
# Patching with InventoryCraftResult.patch
# Patching with PathfinderGoalNearestAttackableTargetInsentient.patch
# Patching with EntityArrow.patch
# Patching with EntityEnderCrystal.patch
# Patching with BlockCauldron.patch
# Patching with BlockVine.patch
# Patching with PlayerConnection.patch
# Patching with ContainerFurnace.patch
# Patching with EntityLiving.patch
# Patching with BlockCactus.patch
# Patching with EntityEvokerFangs.patch
# Patching with TileEntityHopper.patch
# Patching with DispenserRegistry.patch
# Patching with IRecipe.patch
# Patching with EntityInsentient.patch
# Patching with EntityExperienceOrb.patch
# Patching with BlockCake.patch
# Patching with EntityEnderSignal.patch
# Patching with RecipeFireworks.patch
# Patching with EntityGhast.patch
# Patching with EntityShulkerBullet.patch
# Patching with EntityAreaEffectCloud.patch
# Patching with WorldServer.patch
# Patching with EntitySkeletonAbstract.patch
# Patching with ItemStack.patch
# Patching with EntityEnderPearl.patch
# Patching with PathfinderGoalTame.patch
# Patching with PacketDataSerializer.patch
# Patching with ItemChorusFruit.patch
# Patching with PathfinderGoalHurtByTarget.patch
# Patching with EntitySkeletonWither.patch
# Patching with SlotFurnaceResult.patch
# Patching with CommandExecute.patch
# Patching with TileEntityBrewingStand.patch
# Patching with IInventory.patch
# Patching with TileEntityEndGateway.patch
# Patching with EntityMinecartAbstract.patch
# Patching with PathfinderGoalFollowOwner.patch
# Patching with BlockDropper.patch
# Patching with PortalTravelAgent.patch
# Patching with EntityFireworks.patch
# Compiling Bukkit
# [INFO] Scanning for projects...
# [INFO]
# [INFO] ------------------------------------------------------------------------
# [INFO] Building Bukkit 1.12.2-R0.1-SNAPSHOT
# [INFO] ------------------------------------------------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:2.5:clean (default-clean) @ bukkit ---
# [INFO] Deleting /home/wipf/minecraft/Bukkit/target
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:resources (default-resources) @ bukkit ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /home/wipf/minecraft/Bukkit/src/main/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.7.0:compile (default-compile) @ bukkit ---
# [INFO] Changes detected - recompiling the module!
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:testResources (default-testResources) @ bukkit ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /home/wipf/minecraft/Bukkit/src/test/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.7.0:testCompile (default-testCompile) @ bukkit ---
# [INFO] Changes detected - recompiling the module!
# [INFO]
# [INFO] --- maven-surefire-plugin:2.12.4:test (default-test) @ bukkit ---
# [INFO] Surefire report directory: /home/wipf/minecraft/Bukkit/target/surefire-reports
#
# -------------------------------------------------------
#  T E S T S
# -------------------------------------------------------
# Running org.bukkit.InstrumentTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.093 sec
# Running org.bukkit.EntityEffectTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
# Running org.bukkit.ColorTest
# Tests run: 52, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.213 sec
# Running org.bukkit.CoalTypeTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
# Running org.bukkit.ChatPaginatorTest
# Tests run: 15, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.006 sec
# Running org.bukkit.GameModeTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
# Running org.bukkit.GrassSpeciesTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.001 sec
# Running org.bukkit.CropStateTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.001 sec
# Running org.bukkit.ChatColorTest
# Tests run: 10, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.001 sec
# Running org.bukkit.configuration.MemoryConfigurationTest
# Tests run: 6, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.005 sec
# Running org.bukkit.configuration.file.YamlConfigurationTest
# Tests run: 17, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.066 sec
# Running org.bukkit.configuration.MemorySectionTest
# Tests run: 42, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.109 sec
# Running org.bukkit.metadata.LazyMetadataValueTest
# Tests run: 8, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.001 sec
# Running org.bukkit.metadata.MetadataValueAdapterTest
# Tests run: 4, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
# Running org.bukkit.metadata.FixedMetadataValueTest
# Tests run: 3, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
# Running org.bukkit.metadata.MetadataConversionTest
# Tests run: 5, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
# Running org.bukkit.metadata.MetadataStoreTest
# Tests run: 9, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
# Running org.bukkit.MaterialTest
# Tests run: 10, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.058 sec
# Running org.bukkit.util.StringUtilTest
# Tests run: 8, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.006 sec
# Running org.bukkit.util.StringUtilStartsWithTest
# Tests run: 10, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.007 sec
# Running org.bukkit.util.io.BukkitObjectStreamTest
# Tests run: 6, Failures: 0, Errors: 0, Skipped: 3, Time elapsed: 0.138 sec
# Running org.bukkit.materials.MaterialDataTest
# Tests run: 11, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.01 sec
# Running org.bukkit.ArtTest
# Tests run: 5, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.011 sec
# Running org.bukkit.plugin.PluginManagerTest
# Mär 13, 2018 4:37:56 PM org.bukkit.Bukkit setServer
# INFORMATION: This server is running TestServer version Version_null (Implementing API version BukkitVersion_null)
# Tests run: 11, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.163 sec
# Running org.bukkit.plugin.messaging.StandardMessengerTest
# Tests run: 16, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.142 sec
# Running org.bukkit.plugin.TimedRegisteredListenerTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
# Running org.bukkit.DyeColorTest
# Tests run: 80, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.024 sec
# Running org.bukkit.BukkitMirrorTest
# Tests run: 495, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.159 sec
# Running org.bukkit.conversations.ConversationTest
# Tests run: 4, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
# Running org.bukkit.conversations.ValidatingPromptTest
# Tests run: 4, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.022 sec
# Running org.bukkit.conversations.ConversationContextTest
# Tests run: 3, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.004 sec
# Running org.bukkit.WorldTypeTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
# Running org.bukkit.TreeSpeciesTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
# Running org.bukkit.DifficultyTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
# Running org.bukkit.LocationTest
# Tests run: 60, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.057 sec
# Running org.bukkit.event.SyntheticEventTest
# Invk org.bukkit.event.TestEvent@5fa07e12
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.008 sec
# Running org.bukkit.event.PlayerChatTabCompleteEventTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.001 sec
# Running org.bukkit.NoteTest
# Tests run: 17, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.021 sec
# Running org.bukkit.EffectTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
#
# Results :
#
# Tests run: 924, Failures: 0, Errors: 0, Skipped: 3
#
# [INFO]
# [INFO] --- maven-jar-plugin:2.4:jar (default-jar) @ bukkit ---
# [INFO] Building jar: /home/wipf/minecraft/Bukkit/target/bukkit-1.12.2-R0.1-SNAPSHOT.jar
# [INFO]
# [INFO] --- maven-shade-plugin:3.1.0:shade (default) @ bukkit ---
# [INFO] Including commons-lang:commons-lang:jar:2.6 in the shaded jar.
# [INFO] Including com.googlecode.json-simple:json-simple:jar:1.1.1 in the shaded jar.
# [INFO] Including com.google.guava:guava:jar:21.0 in the shaded jar.
# [INFO] Including com.google.code.gson:gson:jar:2.8.0 in the shaded jar.
# [INFO] Including org.yaml:snakeyaml:jar:1.19 in the shaded jar.
# [INFO] Attaching shaded artifact.
# [INFO]
# [INFO] --- maven-install-plugin:2.4:install (default-install) @ bukkit ---
# [INFO] Installing /home/wipf/minecraft/Bukkit/target/bukkit-1.12.2-R0.1-SNAPSHOT.jar to /home/wipf/.m2/repository/org/bukkit/bukkit/1.12.2-R0.1-SNAPSHOT/bukkit-1.12.2-R0.1-SNAPSHOT.jar
# [INFO] Installing /home/wipf/minecraft/Bukkit/pom.xml to /home/wipf/.m2/repository/org/bukkit/bukkit/1.12.2-R0.1-SNAPSHOT/bukkit-1.12.2-R0.1-SNAPSHOT.pom
# [INFO] Installing /home/wipf/minecraft/Bukkit/target/bukkit-1.12.2-R0.1-SNAPSHOT-shaded.jar to /home/wipf/.m2/repository/org/bukkit/bukkit/1.12.2-R0.1-SNAPSHOT/bukkit-1.12.2-R0.1-SNAPSHOT-shaded.jar
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time: 11.956 s
# [INFO] Finished at: 2018-03-13T16:37:58+01:00
# [INFO] Final Memory: 27M/262M
# [INFO] ------------------------------------------------------------------------
# Compiling CraftBukkit
# [INFO] Scanning for projects...
# [INFO]
# [INFO] ------------------------------------------------------------------------
# [INFO] Building CraftBukkit 1.12.2-R0.1-SNAPSHOT
# [INFO] ------------------------------------------------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:2.5:clean (default-clean) @ craftbukkit ---
# [INFO] Deleting /home/wipf/minecraft/CraftBukkit/target
# [INFO]
# [INFO] --- scriptus:0.2:describe (default) @ craftbukkit ---
# [INFO] Set property "describe" to "git-Bukkit-7e94e65"
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:resources (default-resources) @ craftbukkit ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] Copying 4 resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.7.0:compile (default-compile) @ craftbukkit ---
# [INFO] Changes detected - recompiling the module!
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:testResources (default-testResources) @ craftbukkit ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /home/wipf/minecraft/CraftBukkit/src/test/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.7.0:testCompile (default-testCompile) @ craftbukkit ---
# [INFO] Changes detected - recompiling the module!
# [INFO]
# [INFO] --- maven-surefire-plugin:2.20:test (default-test) @ craftbukkit ---
# [INFO]
# [INFO] -------------------------------------------------------
# [INFO]  T E S T S
# [INFO] -------------------------------------------------------
# [INFO] Running org.bukkit.DyeColorsTest
# Mär 13, 2018 4:38:14 PM org.bukkit.Bukkit setServer
# INFORMATION: This server is running org.bukkit.support.DummyServer version null (Implementing API version 1.12.2-R0.1-SNAPSHOT)
# [INFO] Tests run: 32, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 4.37 s - in org.bukkit.DyeColorsTest
# [INFO] Running org.bukkit.potion.PotionTest
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 s - in org.bukkit.potion.PotionTest
# [INFO] Running org.bukkit.craftbukkit.inventory.ItemMetaImplementationOverrideTest
# [INFO] Tests run: 117, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.34 s - in org.bukkit.craftbukkit.inventory.ItemMetaImplementationOverrideTest
# [INFO] Running org.bukkit.craftbukkit.inventory.NMSCraftItemStackTest
# [INFO] Tests run: 2, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 s - in org.bukkit.craftbukkit.inventory.NMSCraftItemStackTest
# [INFO] Running org.bukkit.craftbukkit.inventory.ItemMetaTest
# [INFO] Tests run: 12, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.088 s - in org.bukkit.craftbukkit.inventory.ItemMetaTest
# [INFO] Running org.bukkit.craftbukkit.inventory.FactoryItemMaterialTest
# [INFO] Tests run: 1644, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 1.083 s - in org.bukkit.craftbukkit.inventory.FactoryItemMaterialTest
# [INFO] Running org.bukkit.craftbukkit.inventory.ItemFactoryTest
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 1.595 s - in org.bukkit.craftbukkit.inventory.ItemFactoryTest
# [INFO] Running org.bukkit.craftbukkit.inventory.ItemMetaCloneTest
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.002 s - in org.bukkit.craftbukkit.inventory.ItemMetaCloneTest
# [INFO] Running org.bukkit.craftbukkit.generator.ChunkDataTest
# [INFO] Tests run: 3, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.18 s - in org.bukkit.craftbukkit.generator.ChunkDataTest
# [INFO] Running org.bukkit.ChatTest
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.172 s - in org.bukkit.ChatTest
# [INFO] Running org.bukkit.SoundTest
# [INFO] Tests run: 4, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.029 s - in org.bukkit.SoundTest
# [INFO] Running org.bukkit.PerMaterialTest
# [INFO] Tests run: 6482, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.422 s - in org.bukkit.PerMaterialTest
# [INFO] Running org.bukkit.ParticleTest
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.001 s - in org.bukkit.ParticleTest
# [INFO] Running org.bukkit.MaterialTest
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 s - in org.bukkit.MaterialTest
# [INFO] Running org.bukkit.BiomeTest
# [INFO] Tests run: 2, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 s - in org.bukkit.BiomeTest
# [INFO] Running org.bukkit.ArtTest
# [INFO] Tests run: 3, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 s - in org.bukkit.ArtTest
# [INFO] Running org.bukkit.StatisticsAndAchievementsTest
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 s - in org.bukkit.StatisticsAndAchievementsTest
# [INFO] Running org.bukkit.entity.EnderDragonPhaseTest
# [INFO] Tests run: 3, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 s - in org.bukkit.entity.EnderDragonPhaseTest
# [INFO] Running org.bukkit.WorldTypeTest
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 s - in org.bukkit.WorldTypeTest
# [INFO] Running org.bukkit.map.MapTest
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 s - in org.bukkit.map.MapTest
# [INFO]
# [INFO] Results:
# [INFO]
# [INFO] Tests run: 8313, Failures: 0, Errors: 0, Skipped: 0
# [INFO]
# [INFO]
# [INFO] --- maven-jar-plugin:3.0.2:jar (default-jar) @ craftbukkit ---
# [INFO] Building jar: /home/wipf/minecraft/CraftBukkit/target/craftbukkit-1.12.2-R0.1-SNAPSHOT.jar
# [INFO]
# [INFO] --- maven-shade-plugin:3.1.0:shade (default) @ craftbukkit ---
# [INFO] Including io.netty:netty-all:jar:4.1.21.Final in the shaded jar.
# [INFO] Including org.bukkit:bukkit:jar:1.12.2-R0.1-SNAPSHOT in the shaded jar.
# [INFO] Including commons-lang:commons-lang:jar:2.6 in the shaded jar.
# [INFO] Including com.googlecode.json-simple:json-simple:jar:1.1.1 in the shaded jar.
# [INFO] Including com.google.guava:guava:jar:21.0 in the shaded jar.
# [INFO] Including com.google.code.gson:gson:jar:2.8.0 in the shaded jar.
# [INFO] Including org.yaml:snakeyaml:jar:1.19 in the shaded jar.
# [INFO] Including org.spigotmc:minecraft-server:jar:1.12.2-SNAPSHOT in the shaded jar.
# [INFO] Including net.sf.jopt-simple:jopt-simple:jar:5.0.4 in the shaded jar.
# [INFO] Including jline:jline:jar:2.12.1 in the shaded jar.
# [INFO] Including org.xerial:sqlite-jdbc:jar:3.21.0.1 in the shaded jar.
# [INFO] Including mysql:mysql-connector-java:jar:5.1.45 in the shaded jar.
# [WARNING] minecraft-server-1.12.2-SNAPSHOT.jar, gson-2.8.0.jar define 174 overlapping classes:
# [WARNING]   - com.google.gson.internal.bind.JsonTreeWriter
# [WARNING]   - com.google.gson.internal.bind.TreeTypeAdapter$GsonContextImpl
# [WARNING]   - com.google.gson.internal.Excluder
# [WARNING]   - com.google.gson.JsonDeserializationContext
# [WARNING]   - com.google.gson.Gson$6
# [WARNING]   - com.google.gson.FieldNamingPolicy$5
# [WARNING]   - com.google.gson.internal.$Gson$Types
# [WARNING]   - com.google.gson.internal.LinkedTreeMap$KeySet
# [WARNING]   - com.google.gson.internal.UnsafeAllocator$2
# [WARNING]   - com.google.gson.internal.bind.SqlDateTypeAdapter$1
# [WARNING]   - 164 more...
# [WARNING] minecraft-server-1.12.2-SNAPSHOT.jar, craftbukkit-1.12.2-R0.1-SNAPSHOT.jar define 581 overlapping classes:
# [WARNING]   - net.minecraft.server.DispenserRegistry$2
# [WARNING]   - net.minecraft.server.DispenserRegistry$12
# [WARNING]   - net.minecraft.server.PathfinderGoalNearestAttackableTargetInsentient
# [WARNING]   - net.minecraft.server.BlockWaterLily
# [WARNING]   - net.minecraft.server.PathfinderGoalHurtByTarget
# [WARNING]   - net.minecraft.server.Entity$4
# [WARNING]   - net.minecraft.server.BlockGrass
# [WARNING]   - net.minecraft.server.PlayerChunkMap$5
# [WARNING]   - net.minecraft.server.EntityHorseChestedAbstract
# [WARNING]   - net.minecraft.server.Chunk$1
# [WARNING]   - 571 more...
# [WARNING] netty-all-4.1.21.Final.jar, minecraft-server-1.12.2-SNAPSHOT.jar define 2269 overlapping classes:
# [WARNING]   - io.netty.handler.codec.http.multipart.InterfaceHttpData$HttpDataType
# [WARNING]   - io.netty.resolver.dns.InflightNameResolver$1
# [WARNING]   - io.netty.channel.AbstractChannel$AbstractUnsafe$8
# [WARNING]   - io.netty.handler.codec.smtp.DefaultSmtpRequest
# [WARNING]   - io.netty.handler.codec.redis.RedisMessage
# [WARNING]   - io.netty.handler.codec.memcache.binary.BinaryMemcacheResponse
# [WARNING]   - io.netty.handler.timeout.IdleStateHandler
# [WARNING]   - io.netty.buffer.FixedCompositeByteBuf$Component
# [WARNING]   - io.netty.handler.codec.http.HttpHeaders
# [WARNING]   - io.netty.channel.group.ChannelMatchers$ClassMatcher
# [WARNING]   - 2259 more...
# [WARNING] minecraft-server-1.12.2-SNAPSHOT.jar, guava-21.0.jar define 1837 overlapping classes:
# [WARNING]   - com.google.common.collect.ImmutableMapValues$1
# [WARNING]   - com.google.common.io.LineProcessor
# [WARNING]   - com.google.common.util.concurrent.AbstractService$5
# [WARNING]   - com.google.common.io.BaseEncoding$StandardBaseEncoding$2
# [WARNING]   - com.google.common.io.ByteProcessor
# [WARNING]   - com.google.common.math.package-info
# [WARNING]   - com.google.common.util.concurrent.SimpleTimeLimiter
# [WARNING]   - com.google.common.cache.AbstractCache$StatsCounter
# [WARNING]   - com.google.common.util.concurrent.CycleDetectingLockFactory$Policies
# [WARNING]   - com.google.common.primitives.UnsignedInts$LexicographicalComparator
# [WARNING]   - 1827 more...
# [WARNING] maven-shade-plugin has detected that some class files are
# [WARNING] present in two or more JARs. When this happens, only one
# [WARNING] single version of the class is copied to the uber jar.
# [WARNING] Usually this is not harmful and you can skip these warnings,
# [WARNING] otherwise try to manually exclude artifacts based on
# [WARNING] mvn dependency:tree -Ddetail=true and the above output.
# [WARNING] See http://maven.apache.org/plugins/maven-shade-plugin/
# [INFO] Replacing original artifact with shaded artifact.
# [INFO] Replacing /home/wipf/minecraft/CraftBukkit/target/craftbukkit-1.12.2-R0.1-SNAPSHOT.jar with /home/wipf/minecraft/CraftBukkit/target/craftbukkit-1.12.2-R0.1-SNAPSHOT-shaded.jar
# [INFO] Dependency-reduced POM written at: /home/wipf/minecraft/CraftBukkit/dependency-reduced-pom.xml
# [INFO]
# [INFO] --- maven-install-plugin:2.4:install (default-install) @ craftbukkit ---
# [INFO] Installing /home/wipf/minecraft/CraftBukkit/target/craftbukkit-1.12.2-R0.1-SNAPSHOT.jar to /home/wipf/.m2/repository/org/bukkit/craftbukkit/1.12.2-R0.1-SNAPSHOT/craftbukkit-1.12.2-R0.1-SNAPSHOT.jar
# [INFO] Installing /home/wipf/minecraft/CraftBukkit/dependency-reduced-pom.xml to /home/wipf/.m2/repository/org/bukkit/craftbukkit/1.12.2-R0.1-SNAPSHOT/craftbukkit-1.12.2-R0.1-SNAPSHOT.pom
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time: 37.575 s
# [INFO] Finished at: 2018-03-13T16:38:36+01:00
# [INFO] Final Memory: 24M/414M
# [INFO] ------------------------------------------------------------------------
# Rebuilding Forked projects....
# HEAD ist jetzt bei 02f0647 Add setTarget and getTarget to Slime.
# Resetting Spigot-API to Bukkit...
# HEAD ist jetzt bei 02f0647 Add setTarget and getTarget to Slime.
#   Applying patches to Spigot-API...
# fatal: Es ist keine Auflösung im Gange, es wird nicht fortgesetzt.
# Wende an: POM Changes
# Wende an: Skeleton API Implementations
# Wende an: Spigot Timings
# Wende an: Add PlayerItemDamageEvent
# Wende an: BungeeCord Support
# Wende an: Add Arrow API
# Wende an: Add Particle API
# Wende an: Define EntitySpawnEvent and SpawnerSpawnEvent
# Wende an: Entity Mount and Dismount Events
# Wende an: InventoryClickEvent getClickedInventory
# Wende an: Added getAllSessionData() to the Conversation API.
# Wende an: Player Collision API
# Wende an: Expand Boolean Prompt Values
# Wende an: Add Getter for Entity Invulnerability
# Wende an: Add respawn API.
# Wende an: Implement Locale Getter for Players
# Wende an: Add support for fetching hidden players
# Wende an: Silenceable Lightning API
# Wende an: Remove deprecation on some player lookup methods
# Wende an: Add PlayerSpawnLocationEvent.
# Wende an: Ease ClassLoader Deadlocks Where Possible
# Wende an: Undeprecate Player#updateInventory()V
# Wende an: Added isUnbreakable and setUnbreakable to ItemMeta
# Wende an: BungeeCord Chat API
# Wende an: Add restart API.
#   Patches applied cleanly to Spigot-API
# Von file:///home/wipf/minecraft/CraftBukkit
#  + 9da0778...6eb224d patched    -> origin/patched  (Aktualisierung erzwungen)
# HEAD ist jetzt bei 6eb224d CraftBukkit $ Tue Mar 13 16:37:44 CET 2018
# Resetting Spigot-Server to CraftBukkit...
# HEAD ist jetzt bei 6eb224d CraftBukkit $ Tue Mar 13 16:37:44 CET 2018
#   Applying patches to Spigot-Server...
# fatal: Es ist keine Auflösung im Gange, es wird nicht fortgesetzt.
# Wende an: POM Changes
# Wende an: Skeleton API Implementations
# Wende an: mc-dev imports
# Wende an: Obfuscation Helpers
# Wende an: Spigot Configuration
# Wende an: Crop Growth Rates
# Wende an: Merge tweaks and configuration
# Wende an: Async Operation Catching
# Wende an: View Distance
# Wende an: Spigot Timings
# Wende an: Fix Mob Spawning Relative to View Distance
# Wende an: Handle Null Tile Entities
# Wende an: Item Despawn Rate
# Wende an: Entity Activation Range
# Wende an: Metrics
# Wende an: PlayerItemDamageEvent
# Wende an: Entity Tracking Ranges
# Wende an: Thread Naming and Tweaks
# Wende an: Close Unloaded Save Files
# Wende an: Remove -o Option
# Wende an: Implement Arrow API
# Wende an: Hopper Customisations
# Wende an: Allow Disabling of Command Logging
# Wende an: Allow Disabling of Command TabComplete
# Wende an: Configurable Messages
# Wende an: Allow Disabling of Random Lighting Updates
# Wende an: Properly Close Inventories
# Wende an: Disallow Interaction With Self
# Wende an: Entity Mount and Dismount Events
# Wende an: Prevent Ghost Players Caused by Plugins
# Wende an: Plug World Unload Memory Leak
# Wende an: Player Collision API
# Wende an: Fully Disable Snooper When Not Required
# Wende an: Add Getter for Entity Invulnerability
# Wende an: Allow Disabling of 1.6.3 Structure Saving
# Wende an: Don't Special Case X Move Value
# Wende an: Implement respawn API.
# Wende an: Arrow Despawn Rate
# Wende an: Watchdog Thread.
# Wende an: Fix some chunks not being sent to the client
# Wende an: Fix Broken Async Chat
# Wende an: Fire PreLogin Events in Offline Mode
# Wende an: BungeeCord Support
# Wende an: Allow Disabling Zombie Villager Aggression
# Wende an: Configurable Amount of Netty Threads
# Wende an: Prevent Mineshaft Saving
# Wende an: Log Cause of Unexpected Exceptions
# Wende an: Particle API
# Wende an: Save ticks lived to nbttag
# Wende an: Add Option to Nerf Mobs from Spawners
# Wende an: Disable Connected Check on setScoreboard
# Wende an: Add Late Bind Option
# Wende an: Allow statistics to be disabled/forced
# Wende an: Try and Debug Crash Reports Crashing
# Wende an: Improve AutoSave Mechanism
# Wende an: Catch stalling on corrupted map data / NBT arrays.
# Wende an: Allow toggling of ZombiePigmen spawning in portal blocks
# Wende an: Highly Optimized Tick Loop
# Wende an: Configurable Ping Sample Size
# Wende an: Add Optional Tick Shuffling
# Wende an: Implement Locale Getter for Players
# Wende an: Spam Filter Exclusions
# Wende an: Add Option to Silence CommandBlock Console
# Wende an: Add support for fetching hidden players
# Wende an: Allow Disabling Creative Item Filter
# Wende an: Cap Channel Registrations
# Wende an: Allow vanilla commands to be the main version of a command
# Wende an: Implement Silenceable Lightning API
# Wende an: Use one PermissibleBase for all Command Blocks
# Wende an: Prevent hoppers from loading chunks
# Wende an: Guard Entity List
# Wende an: Fix ConcurrentModificationException while being idle kicked in a vehicle
# Wende an: Cancellable WitherSkull potion effect
# Wende an: Descriptive kick reasons instead of Nope!
# Wende an: Configurable dragon death and wither spawn sounds
# Wende an: Display 'Spigot' in client crashes, server lists and Mojang stats
# Wende an: Treat Bungee as Online Mode
# Wende an: Add Conversion Message
# Wende an: Print Stack on InternalException
# Wende an: Use Offline Player Data Once if Required.
# Wende an: Use Provided Case for Non Existent Offline Players
# Wende an: Check for blank OfflinePlayer Names
# Wende an: Fix Player Banning
# Wende an: Fix ban expire dates.
# Wende an: Correct Ban Expiration
# Wende an: Log null TileEntity Owner
# Wende an: Convert player skulls async
# Wende an: Prevent NoClassDefError crash and notify on crash
# Wende an: Check Skull canPlace
# Wende an: Fix race condition that could kill connections before they were initiated
# Wende an: Configurable UserCache cap
# Wende an: Implement PlayerSpawnLocationEvent.
# Wende an: Cap Objective Score Length
# Wende an: Process conversation input on the main thread. Fixes BUKKIT-5611
# Wende an: Configurable save-on-stop-only for UserCache
# Wende an: Prevent Unbounded IntCache Growth
# Wende an: Cross World Entity Teleportation
# Wende an: Limit block placement/interaction packets
# Wende an: Better item validation
# Wende an: Further Seed Customisation
# Wende an: Disable ResourceLeakDetector
# Wende an: Add More Information to session.lock Errors
# Wende an: Safer JSON Loading
# Wende an: Add CommandLine EULA Flag
# Wende an: Fix for enchanting table wiping meta when placing stacked items
# Wende an: Don't spawn bonus ocelots when plugins spawn ocelots
# Wende an: Prevent a crash involving attributes
# Wende an: Make "moved wrongly" limit configurable
# Wende an: Fix Null Tile Entity Worlds
# Wende an: Make "moved too quickly" limit configurable
# Wende an: Apply NBTReadLimiter to more things.
# Wende an: Allow Attribute Capping.
# Wende an: Only fetch an online UUID in online mode
# Wende an: Filter attribute modifiers which cause the attribute to go out of its range
# Wende an: Plug WorldMap Memory Leak
# Wende an: Fix Corrupted Trapped Chest
# Wende an: Remove uneeded validation
# Wende an: Add Hunger Config Values
# Wende an: Make debug logging togglable.
# Wende an: Limit TNT Detonations per tick
# Wende an: Added isUnbreakable and setUnbreakable to ItemMeta
# Wende an: Configurable Hanging Tick
# Wende an: Refactor ItemDoor Place
# Wende an: BungeeCord Chat API
# Wende an: Use Standard List for EntitySlices.
# Wende an: Allow Capping (Tile)Entity Tick Time.
# Wende an: Use FastMatches for ItemStack Dirty Check
# Wende an: Use CLQ for main thread tasks.
# Wende an: map decoration fix
# Wende an: Use Map for getPlayer(String) lookup.
# Wende an: Clear Packet Queue on Disconnect
# Wende an: Implement SpawnerSpawnEvent.
# Wende an: Don't tick blocks if neighbor chunks aren't loaded
# Wende an: Branchless NibbleArray
# Wende an: Replace chunk loading / unloading rate throttling.
# Wende an: Configurable Advancement Disabling
# Wende an: Make unloaded chunk saving more asynchronous
# Wende an: Allow changing minimum squid spawn range
# Wende an: Cache BlockState.hashCode
#   Patches applied cleanly to Spigot-Server
# *** Spigot patches applied!
# Compiling Spigot & Spigot-API
# [INFO] Scanning for projects...
# [INFO] ------------------------------------------------------------------------
# [INFO] Reactor Build Order:
# [INFO]
# [INFO] Spigot-API
# [INFO] Spigot-Parent
# [INFO] Spigot
# [INFO]
# [INFO] ------------------------------------------------------------------------
# [INFO] Building Spigot-API 1.12.2-R0.1-SNAPSHOT
# [INFO] ------------------------------------------------------------------------
# Downloading: https://hub.spigotmc.org/nexus/content/groups/public/net/md-5/bungeecord-chat/1.12-SNAPSHOT/maven-metadata.xml
# Progress (1): 1.2 kB
#
# Downloaded: https://hub.spigotmc.org/nexus/content/groups/public/net/md-5/bungeecord-chat/1.12-SNAPSHOT/maven-metadata.xml (1.2 kB at 1.3 kB/s)
# Downloading: https://hub.spigotmc.org/nexus/content/groups/public/net/md-5/bungeecord-chat/1.12-SNAPSHOT/bungeecord-chat-1.12-20180307.023022-71.pom
# Progress (1): 1.1 kB
#
# Downloaded: https://hub.spigotmc.org/nexus/content/groups/public/net/md-5/bungeecord-chat/1.12-SNAPSHOT/bungeecord-chat-1.12-20180307.023022-71.pom (1.1 kB at 3.9 kB/s)
# Downloading: https://hub.spigotmc.org/nexus/content/groups/public/net/md-5/bungeecord-parent/1.12-SNAPSHOT/maven-metadata.xml
# Progress (1): 602 B
#
# Downloaded: https://hub.spigotmc.org/nexus/content/groups/public/net/md-5/bungeecord-parent/1.12-SNAPSHOT/maven-metadata.xml (602 B at 2.1 kB/s)
# Downloading: https://hub.spigotmc.org/nexus/content/groups/public/net/md-5/bungeecord-parent/1.12-SNAPSHOT/bungeecord-parent-1.12-20180307.023012-71.pom
# Progress (1): 1.2 kB
# Progress (1): 2.7 kB
# Progress (1): 5.6 kB
# Progress (1): 6.5 kB
#
# Downloaded: https://hub.spigotmc.org/nexus/content/groups/public/net/md-5/bungeecord-parent/1.12-SNAPSHOT/bungeecord-parent-1.12-20180307.023012-71.pom (6.5 kB at 17 kB/s)
# Downloading: https://hub.spigotmc.org/nexus/content/groups/public/net/md-5/bungeecord-chat/1.12-SNAPSHOT/bungeecord-chat-1.12-20180307.023022-71.jar
# Progress (1): 0.9/73 kB
# Progress (1): 2.3/73 kB
# Progress (1): 3.6/73 kB
# Progress (1): 5.0/73 kB
# Progress (1): 6.4/73 kB
# Progress (1): 7.7/73 kB
# Progress (1): 9.1/73 kB
# Progress (1): 10/73 kB
# Progress (1): 12/73 kB
# Progress (1): 13/73 kB
# Progress (1): 14/73 kB
# Progress (1): 15/73 kB
# Progress (1): 16/73 kB
# Progress (1): 18/73 kB
# Progress (1): 19/73 kB
# Progress (1): 21/73 kB
# Progress (1): 22/73 kB
# Progress (1): 23/73 kB
# Progress (1): 25/73 kB
# Progress (1): 26/73 kB
# Progress (1): 27/73 kB
# Progress (1): 29/73 kB
# Progress (1): 30/73 kB
# Progress (1): 31/73 kB
# Progress (1): 33/73 kB
# Progress (1): 34/73 kB
# Progress (1): 36/73 kB
# Progress (1): 37/73 kB
# Progress (1): 41/73 kB
# Progress (1): 41/73 kB
# Progress (1): 43/73 kB
# Progress (1): 47/73 kB
# Progress (1): 47/73 kB
# Progress (1): 51/73 kB
# Progress (1): 51/73 kB
# Progress (1): 55/73 kB
# Progress (1): 56/73 kB
# Progress (1): 59/73 kB
# Progress (1): 63/73 kB
# Progress (1): 64/73 kB
# Progress (1): 68/73 kB
# Progress (1): 68/73 kB
# Progress (1): 72/73 kB
# Progress (1): 72/73 kB
# Progress (1): 73 kB
#
# Downloaded: https://hub.spigotmc.org/nexus/content/groups/public/net/md-5/bungeecord-chat/1.12-SNAPSHOT/bungeecord-chat-1.12-20180307.023022-71.jar (73 kB at 127 kB/s)
# [INFO]
# [INFO] --- maven-clean-plugin:2.5:clean (default-clean) @ spigot-api ---
# [INFO] Deleting /home/wipf/minecraft/Spigot/Spigot-API/target
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:resources (default-resources) @ spigot-api ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /home/wipf/minecraft/Spigot/Spigot-API/src/main/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.7.0:compile (default-compile) @ spigot-api ---
# [INFO] Changes detected - recompiling the module!
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:testResources (default-testResources) @ spigot-api ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /home/wipf/minecraft/Spigot/Spigot-API/src/test/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.7.0:testCompile (default-testCompile) @ spigot-api ---
# [INFO] Changes detected - recompiling the module!
# [INFO]
# [INFO] --- maven-surefire-plugin:2.12.4:test (default-test) @ spigot-api ---
# [INFO] Surefire report directory: /home/wipf/minecraft/Spigot/Spigot-API/target/surefire-reports
#
# -------------------------------------------------------
#  T E S T S
# -------------------------------------------------------
# Running org.bukkit.InstrumentTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.046 sec
# Running org.bukkit.EntityEffectTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.002 sec
# Running org.bukkit.ColorTest
# Tests run: 52, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.13 sec
# Running org.bukkit.CoalTypeTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
# Running org.bukkit.ChatPaginatorTest
# Tests run: 15, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.008 sec
# Running org.bukkit.GameModeTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
# Running org.bukkit.GrassSpeciesTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.004 sec
# Running org.bukkit.CropStateTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
# Running org.bukkit.ChatColorTest
# Tests run: 10, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
# Running org.bukkit.configuration.MemoryConfigurationTest
# Tests run: 6, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.004 sec
# Running org.bukkit.configuration.file.YamlConfigurationTest
# Tests run: 17, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.065 sec
# Running org.bukkit.configuration.MemorySectionTest
# Tests run: 42, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.107 sec
# Running org.bukkit.metadata.LazyMetadataValueTest
# Tests run: 8, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
# Running org.bukkit.metadata.MetadataValueAdapterTest
# Tests run: 4, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.006 sec
# Running org.bukkit.metadata.FixedMetadataValueTest
# Tests run: 3, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
# Running org.bukkit.metadata.MetadataConversionTest
# Tests run: 5, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
# Running org.bukkit.metadata.MetadataStoreTest
# Tests run: 9, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.008 sec
# Running org.bukkit.MaterialTest
# Tests run: 10, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.063 sec
# Running org.bukkit.util.StringUtilTest
# Tests run: 8, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.005 sec
# Running org.bukkit.util.StringUtilStartsWithTest
# Tests run: 10, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.01 sec
# Running org.bukkit.util.io.BukkitObjectStreamTest
# Tests run: 6, Failures: 0, Errors: 0, Skipped: 3, Time elapsed: 0.086 sec
# Running org.bukkit.materials.MaterialDataTest
# Tests run: 11, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.012 sec
# Running org.bukkit.ArtTest
# Tests run: 5, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.012 sec
# Running org.bukkit.plugin.PluginManagerTest
# Mär 13, 2018 4:38:56 PM org.bukkit.Bukkit setServer
# INFORMATION: This server is running TestServer version Version_null (Implementing API version BukkitVersion_null)
# Tests run: 11, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.07 sec
# Running org.bukkit.plugin.messaging.StandardMessengerTest
# Tests run: 16, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.144 sec
# Running org.bukkit.plugin.TimedRegisteredListenerTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
# Running org.bukkit.DyeColorTest
# Tests run: 80, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.022 sec
# Running org.bukkit.BukkitMirrorTest
# Tests run: 500, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.134 sec
# Running org.bukkit.conversations.ConversationTest
# Tests run: 4, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.004 sec
# Running org.bukkit.conversations.ValidatingPromptTest
# Tests run: 4, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.008 sec
# Running org.bukkit.conversations.ConversationContextTest
# Tests run: 3, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.002 sec
# Running org.bukkit.WorldTypeTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.002 sec
# Running org.bukkit.TreeSpeciesTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.001 sec
# Running org.bukkit.DifficultyTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.001 sec
# Running org.bukkit.LocationTest
# Tests run: 60, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.024 sec
# Running org.bukkit.event.SyntheticEventTest
# Invk org.bukkit.event.TestEvent@6a6afff2
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.007 sec
# Running org.bukkit.event.PlayerChatTabCompleteEventTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.001 sec
# Running org.bukkit.NoteTest
# Tests run: 17, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.018 sec
# Running org.bukkit.EffectTest
# Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 sec
#
# Results :
#
# Tests run: 929, Failures: 0, Errors: 0, Skipped: 3
#
# [INFO]
# [INFO] --- maven-jar-plugin:2.4:jar (default-jar) @ spigot-api ---
# [INFO] Building jar: /home/wipf/minecraft/Spigot/Spigot-API/target/spigot-api-1.12.2-R0.1-SNAPSHOT.jar
# [INFO]
# [INFO] --- maven-shade-plugin:3.1.0:shade (default) @ spigot-api ---
# [INFO] Including commons-lang:commons-lang:jar:2.6 in the shaded jar.
# [INFO] Including com.googlecode.json-simple:json-simple:jar:1.1.1 in the shaded jar.
# [INFO] Including com.google.guava:guava:jar:21.0 in the shaded jar.
# [INFO] Including com.google.code.gson:gson:jar:2.8.0 in the shaded jar.
# [INFO] Including org.yaml:snakeyaml:jar:1.19 in the shaded jar.
# [INFO] Including net.md-5:bungeecord-chat:jar:1.12-SNAPSHOT in the shaded jar.
# [INFO] Attaching shaded artifact.
# [INFO]
# [INFO] --- maven-install-plugin:2.4:install (default-install) @ spigot-api ---
# [INFO] Installing /home/wipf/minecraft/Spigot/Spigot-API/target/spigot-api-1.12.2-R0.1-SNAPSHOT.jar to /home/wipf/.m2/repository/org/spigotmc/spigot-api/1.12.2-R0.1-SNAPSHOT/spigot-api-1.12.2-R0.1-SNAPSHOT.jar
# [INFO] Installing /home/wipf/minecraft/Spigot/Spigot-API/pom.xml to /home/wipf/.m2/repository/org/spigotmc/spigot-api/1.12.2-R0.1-SNAPSHOT/spigot-api-1.12.2-R0.1-SNAPSHOT.pom
# [INFO] Installing /home/wipf/minecraft/Spigot/Spigot-API/target/spigot-api-1.12.2-R0.1-SNAPSHOT-shaded.jar to /home/wipf/.m2/repository/org/spigotmc/spigot-api/1.12.2-R0.1-SNAPSHOT/spigot-api-1.12.2-R0.1-SNAPSHOT-shaded.jar
# [INFO]
# [INFO] ------------------------------------------------------------------------
# [INFO] Building Spigot-Parent dev-SNAPSHOT
# [INFO] ------------------------------------------------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:2.5:clean (default-clean) @ spigot-parent ---
# [INFO]
# [INFO] --- maven-install-plugin:2.4:install (default-install) @ spigot-parent ---
# [INFO] Installing /home/wipf/minecraft/Spigot/pom.xml to /home/wipf/.m2/repository/org/spigotmc/spigot-parent/dev-SNAPSHOT/spigot-parent-dev-SNAPSHOT.pom
# [INFO]
# [INFO] ------------------------------------------------------------------------
# [INFO] Building Spigot 1.12.2-R0.1-SNAPSHOT
# [INFO] ------------------------------------------------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:2.5:clean (default-clean) @ spigot ---
# [INFO] Deleting /home/wipf/minecraft/Spigot/Spigot-Server/target
# [INFO]
# [INFO] --- scriptus:0.2:describe (ex-spigot) @ spigot ---
# [INFO] Set property "spigot.desc" to "git-Spigot-c3093ef"
# [INFO]
# [INFO] --- scriptus:0.2:describe (ex-craftbukkit) @ spigot ---
# [INFO] Set property "craftbukkit.desc" to "-7e94e65"
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:resources (default-resources) @ spigot ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] Copying 4 resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.7.0:compile (default-compile) @ spigot ---
# [INFO] Changes detected - recompiling the module!
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:testResources (default-testResources) @ spigot ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /home/wipf/minecraft/Spigot/Spigot-Server/src/test/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.7.0:testCompile (default-testCompile) @ spigot ---
# [INFO] Changes detected - recompiling the module!
# [INFO]
# [INFO] --- maven-surefire-plugin:2.20:test (default-test) @ spigot ---
# [INFO]
# [INFO] -------------------------------------------------------
# [INFO]  T E S T S
# [INFO] -------------------------------------------------------
# [INFO] Running org.bukkit.DyeColorsTest
# Mär 13, 2018 4:39:09 PM org.bukkit.Bukkit setServer
# INFORMATION: This server is running org.bukkit.support.DummyServer version null (Implementing API version 1.12.2-R0.1-SNAPSHOT)
# [INFO] Tests run: 32, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 3.449 s - in org.bukkit.DyeColorsTest
# [INFO] Running org.bukkit.potion.PotionTest
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.001 s - in org.bukkit.potion.PotionTest
# [INFO] Running org.bukkit.craftbukkit.inventory.ItemMetaImplementationOverrideTest
# [INFO] Tests run: 117, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.342 s - in org.bukkit.craftbukkit.inventory.ItemMetaImplementationOverrideTest
# [INFO] Running org.bukkit.craftbukkit.inventory.NMSCraftItemStackTest
# [INFO] Tests run: 2, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.018 s - in org.bukkit.craftbukkit.inventory.NMSCraftItemStackTest
# [INFO] Running org.bukkit.craftbukkit.inventory.ItemMetaTest
# [INFO] Tests run: 12, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.102 s - in org.bukkit.craftbukkit.inventory.ItemMetaTest
# [INFO] Running org.bukkit.craftbukkit.inventory.FactoryItemMaterialTest
# [INFO] Tests run: 1644, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 1.244 s - in org.bukkit.craftbukkit.inventory.FactoryItemMaterialTest
# [INFO] Running org.bukkit.craftbukkit.inventory.ItemFactoryTest
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 1.303 s - in org.bukkit.craftbukkit.inventory.ItemFactoryTest
# [INFO] Running org.bukkit.craftbukkit.inventory.ItemMetaCloneTest
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 s - in org.bukkit.craftbukkit.inventory.ItemMetaCloneTest
# [INFO] Running org.bukkit.craftbukkit.generator.ChunkDataTest
# [INFO] Tests run: 3, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.09 s - in org.bukkit.craftbukkit.generator.ChunkDataTest
# [INFO] Running org.bukkit.ChatTest
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.004 s - in org.bukkit.ChatTest
# [INFO] Running org.bukkit.SoundTest
# [INFO] Tests run: 4, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.025 s - in org.bukkit.SoundTest
# [INFO] Running org.bukkit.NibbleArrayTest
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.002 s - in org.bukkit.NibbleArrayTest
# [INFO] Running org.bukkit.PerMaterialTest
# [INFO] Tests run: 6482, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.274 s - in org.bukkit.PerMaterialTest
# [INFO] Running org.bukkit.ParticleTest
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 s - in org.bukkit.ParticleTest
# [INFO] Running org.bukkit.MaterialTest
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 s - in org.bukkit.MaterialTest
# [INFO] Running org.bukkit.BiomeTest
# [INFO] Tests run: 2, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.003 s - in org.bukkit.BiomeTest
# [INFO] Running org.bukkit.ArtTest
# [INFO] Tests run: 3, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.005 s - in org.bukkit.ArtTest
# [INFO] Running org.bukkit.StatisticsAndAchievementsTest
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.024 s - in org.bukkit.StatisticsAndAchievementsTest
# [INFO] Running org.bukkit.entity.EnderDragonPhaseTest
# [INFO] Tests run: 3, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.055 s - in org.bukkit.entity.EnderDragonPhaseTest
# [INFO] Running org.bukkit.WorldTypeTest
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0 s - in org.bukkit.WorldTypeTest
# [INFO] Running org.bukkit.map.MapTest
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.001 s - in org.bukkit.map.MapTest
# [INFO]
# [INFO] Results:
# [INFO]
# [INFO] Tests run: 8314, Failures: 0, Errors: 0, Skipped: 0
# [INFO]
# [INFO]
# [INFO] --- maven-jar-plugin:3.0.2:jar (default-jar) @ spigot ---
# [INFO] Building jar: /home/wipf/minecraft/Spigot/Spigot-Server/target/spigot-1.12.2-R0.1-SNAPSHOT.jar
# [INFO]
# [INFO] --- maven-shade-plugin:3.1.0:shade (default) @ spigot ---
# [INFO] Including io.netty:netty-all:jar:4.1.21.Final in the shaded jar.
# [INFO] Including org.spigotmc:spigot-api:jar:1.12.2-R0.1-SNAPSHOT in the shaded jar.
# [INFO] Including commons-lang:commons-lang:jar:2.6 in the shaded jar.
# [INFO] Including com.googlecode.json-simple:json-simple:jar:1.1.1 in the shaded jar.
# [INFO] Including com.google.guava:guava:jar:21.0 in the shaded jar.
# [INFO] Including com.google.code.gson:gson:jar:2.8.0 in the shaded jar.
# [INFO] Including org.yaml:snakeyaml:jar:1.19 in the shaded jar.
# [INFO] Including net.md-5:bungeecord-chat:jar:1.12-SNAPSHOT in the shaded jar.
# [INFO] Including org.spigotmc:minecraft-server:jar:1.12.2-SNAPSHOT in the shaded jar.
# [INFO] Including net.sf.jopt-simple:jopt-simple:jar:5.0.4 in the shaded jar.
# [INFO] Including jline:jline:jar:2.12.1 in the shaded jar.
# [INFO] Including org.xerial:sqlite-jdbc:jar:3.21.0.1 in the shaded jar.
# [INFO] Including mysql:mysql-connector-java:jar:5.1.45 in the shaded jar.
# [INFO] Including net.sf.trove4j:trove4j:jar:3.0.3 in the shaded jar.
# [WARNING] minecraft-server-1.12.2-SNAPSHOT.jar, gson-2.8.0.jar define 174 overlapping classes:
# [WARNING]   - com.google.gson.internal.bind.JsonTreeWriter
# [WARNING]   - com.google.gson.internal.bind.TreeTypeAdapter$GsonContextImpl
# [WARNING]   - com.google.gson.internal.Excluder
# [WARNING]   - com.google.gson.JsonDeserializationContext
# [WARNING]   - com.google.gson.Gson$6
# [WARNING]   - com.google.gson.FieldNamingPolicy$5
# [WARNING]   - com.google.gson.internal.$Gson$Types
# [WARNING]   - com.google.gson.internal.LinkedTreeMap$KeySet
# [WARNING]   - com.google.gson.internal.UnsafeAllocator$2
# [WARNING]   - com.google.gson.internal.bind.SqlDateTypeAdapter$1
# [WARNING]   - 164 more...
# [WARNING] netty-all-4.1.21.Final.jar, minecraft-server-1.12.2-SNAPSHOT.jar define 2269 overlapping classes:
# [WARNING]   - io.netty.handler.codec.http.multipart.InterfaceHttpData$HttpDataType
# [WARNING]   - io.netty.resolver.dns.InflightNameResolver$1
# [WARNING]   - io.netty.channel.AbstractChannel$AbstractUnsafe$8
# [WARNING]   - io.netty.handler.codec.smtp.DefaultSmtpRequest
# [WARNING]   - io.netty.handler.codec.redis.RedisMessage
# [WARNING]   - io.netty.handler.codec.memcache.binary.BinaryMemcacheResponse
# [WARNING]   - io.netty.handler.timeout.IdleStateHandler
# [WARNING]   - io.netty.buffer.FixedCompositeByteBuf$Component
# [WARNING]   - io.netty.handler.codec.http.HttpHeaders
# [WARNING]   - io.netty.channel.group.ChannelMatchers$ClassMatcher
# [WARNING]   - 2259 more...
# [WARNING] spigot-1.12.2-R0.1-SNAPSHOT.jar, minecraft-server-1.12.2-SNAPSHOT.jar define 625 overlapping classes:
# [WARNING]   - net.minecraft.server.DispenserRegistry$2
# [WARNING]   - net.minecraft.server.DispenserRegistry$12
# [WARNING]   - net.minecraft.server.PathfinderGoalNearestAttackableTargetInsentient
# [WARNING]   - net.minecraft.server.BlockWaterLily
# [WARNING]   - net.minecraft.server.PathfinderGoalHurtByTarget
# [WARNING]   - net.minecraft.server.Entity$4
# [WARNING]   - net.minecraft.server.BlockGrass
# [WARNING]   - net.minecraft.server.PlayerChunkMap$5
# [WARNING]   - net.minecraft.server.EntityHorseChestedAbstract
# [WARNING]   - net.minecraft.server.Chunk$1
# [WARNING]   - 615 more...
# [WARNING] minecraft-server-1.12.2-SNAPSHOT.jar, guava-21.0.jar define 1837 overlapping classes:
# [WARNING]   - com.google.common.collect.ImmutableMapValues$1
# [WARNING]   - com.google.common.io.LineProcessor
# [WARNING]   - com.google.common.util.concurrent.AbstractService$5
# [WARNING]   - com.google.common.io.BaseEncoding$StandardBaseEncoding$2
# [WARNING]   - com.google.common.io.ByteProcessor
# [WARNING]   - com.google.common.math.package-info
# [WARNING]   - com.google.common.util.concurrent.SimpleTimeLimiter
# [WARNING]   - com.google.common.cache.AbstractCache$StatsCounter
# [WARNING]   - com.google.common.util.concurrent.CycleDetectingLockFactory$Policies
# [WARNING]   - com.google.common.primitives.UnsignedInts$LexicographicalComparator
# [WARNING]   - 1827 more...
# [WARNING] maven-shade-plugin has detected that some class files are
# [WARNING] present in two or more JARs. When this happens, only one
# [WARNING] single version of the class is copied to the uber jar.
# [WARNING] Usually this is not harmful and you can skip these warnings,
# [WARNING] otherwise try to manually exclude artifacts based on
# [WARNING] mvn dependency:tree -Ddetail=true and the above output.
# [WARNING] See http://maven.apache.org/plugins/maven-shade-plugin/
# [INFO] Replacing original artifact with shaded artifact.
# [INFO] Replacing /home/wipf/minecraft/Spigot/Spigot-Server/target/spigot-1.12.2-R0.1-SNAPSHOT.jar with /home/wipf/minecraft/Spigot/Spigot-Server/target/spigot-1.12.2-R0.1-SNAPSHOT-shaded.jar
# [INFO] Dependency-reduced POM written at: /home/wipf/minecraft/Spigot/Spigot-Server/dependency-reduced-pom.xml
# [INFO]
# [INFO] --- maven-install-plugin:2.4:install (default-install) @ spigot ---
# [INFO] Installing /home/wipf/minecraft/Spigot/Spigot-Server/target/spigot-1.12.2-R0.1-SNAPSHOT.jar to /home/wipf/.m2/repository/org/spigotmc/spigot/1.12.2-R0.1-SNAPSHOT/spigot-1.12.2-R0.1-SNAPSHOT.jar
# [INFO] Installing /home/wipf/minecraft/Spigot/Spigot-Server/dependency-reduced-pom.xml to /home/wipf/.m2/repository/org/spigotmc/spigot/1.12.2-R0.1-SNAPSHOT/spigot-1.12.2-R0.1-SNAPSHOT.pom
# [INFO] ------------------------------------------------------------------------
# [INFO] Reactor Summary:
# [INFO]
# [INFO] Spigot-API ......................................... SUCCESS [ 11.449 s]
# [INFO] Spigot-Parent ...................................... SUCCESS [  0.112 s]
# [INFO] Spigot ............................................. SUCCESS [ 33.702 s]
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time: 45.398 s
# [INFO] Finished at: 2018-03-13T16:39:32+01:00
# [INFO] Final Memory: 30M/542M
# [INFO] ------------------------------------------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Success! Everything compiled successfully. Copying final .jar files now.
# Copying craftbukkit-1.12.2-R0.1-SNAPSHOT.jar to /home/wipf/minecraft/./craftbukkit-1.12.2.jar
#   - Saved as ./craftbukkit-1.12.2.jar
# Copying spigot-1.12.2-R0.1-SNAPSHOT.jar to /home/wipf/minecraft/./spigot-1.12.2.jar
#   - Saved as ./spigot-1.12.2.jar

# %%
mv  spigot-1.12.2.jar spigot.jar

# %%
cp spigot.jar server/spigot.jar

# %%
cd /home/wipf/minecraft/server
java -jar -Xmx2048M spigot.jar
# Out:
# Loading libraries, please wait...
# [16:43:27 INFO]: Starting minecraft server version 1.12.2
# [16:43:27 INFO]: Loading properties
# [16:43:27 INFO]: Default game type: SURVIVAL
# [16:43:27 INFO]: This server is running CraftBukkit version git-Spigot-c3093ef-7e94e65 (MC: 1.12.2) (Implementing API version 1.12.2-R0.1-SNAPSHOT)
# [16:43:27 INFO]: Using 4 threads for Netty based IO
# [16:43:27 INFO]: Server Ping Player Sample Count: 12
# [16:43:27 INFO]: Debug logging is disabled
# [16:43:27 INFO]: Generating keypair
# [16:43:27 INFO]: Starting Minecraft server on *:25565
# [16:43:27 INFO]: Using epoll channel type
# [16:43:28 INFO]: Set PluginClassLoader as parallel capable
# [16:43:28 INFO]: [dynmap] Loading dynmap v2.5-Dev201706100405
# [16:43:28 INFO]: [dynmap] version=git-Spigot-c3093ef-7e94e65 (MC: 1.12.2)
# [16:43:28 INFO]: [dynmap] Mod Support API available
# [16:43:28 INFO]: [MultiWorld] Loading MultiWorld v5.2.8
# [16:43:28 INFO]: [WorldEdit] Loading WorldEdit v6.1.9-SNAPSHOT;3733-52263ac
# [16:43:28 INFO]: [Backpacks] Loading Backpacks v0.1.3
# [16:43:28 INFO]: **** Beginning UUID conversion, this may take A LONG time ****
# [16:43:28 INFO]: Preparing level "world"
# [16:43:28 INFO]: -------- World Settings For [world] --------
# [16:43:28 INFO]: Mob Spawn Range: 4
# [16:43:28 INFO]: Cactus Growth Modifier: 100%
# [16:43:28 INFO]: Cane Growth Modifier: 100%
# [16:43:28 INFO]: Melon Growth Modifier: 100%
# [16:43:28 INFO]: Mushroom Growth Modifier: 100%
# [16:43:28 INFO]: Pumpkin Growth Modifier: 100%
# [16:43:28 INFO]: Sapling Growth Modifier: 100%
# [16:43:28 INFO]: Wheat Growth Modifier: 100%
# [16:43:28 INFO]: NetherWart Growth Modifier: 100%
# [16:43:28 INFO]: Vine Growth Modifier: 100%
# [16:43:28 INFO]: Cocoa Growth Modifier: 100%
# [16:43:28 INFO]: Entity Activation Range: An 32 / Mo 32 / Mi 16
# [16:43:28 INFO]: Entity Tracking Range: Pl 48 / An 48 / Mo 48 / Mi 32 / Other 64
# [16:43:28 INFO]: Hopper Transfer: 8 Hopper Check: 1 Hopper Amount: 1
# [16:43:28 INFO]: Random Lighting Updates: false
# [16:43:28 INFO]: Structure Info Saving: true
# [16:43:28 INFO]: Custom Map Seeds:  Village: 10387312 Feature: 14357617 Monument: 10387313 Slime: 987234911
# [16:43:28 INFO]: Max TNT Explosions: 100
# [16:43:28 INFO]: Tile Max Tick Time: 50ms Entity max Tick Time: 50ms
# [16:43:28 INFO]: Item Despawn Rate: 6000
# [16:43:28 INFO]: Item Merge Radius: 2.5
# [16:43:28 INFO]: Arrow Despawn Rate: 1200
# [16:43:28 INFO]: Allow Zombie Pigmen to spawn from portal blocks: true
# [16:43:28 INFO]: View Distance: 10
# [16:43:28 INFO]: Zombie Aggressive Towards Villager: true
# [16:43:28 INFO]: Experience Merge Radius: 3.0
# [16:43:28 INFO]: Nerfing mobs spawned from spawners: false
# [16:43:28 INFO]: -------- World Settings For [world_nether] --------
# [16:43:28 INFO]: Mob Spawn Range: 4
# [16:43:28 INFO]: Cactus Growth Modifier: 100%
# [16:43:28 INFO]: Cane Growth Modifier: 100%
# [16:43:28 INFO]: Melon Growth Modifier: 100%
# [16:43:28 INFO]: Mushroom Growth Modifier: 100%
# [16:43:28 INFO]: Pumpkin Growth Modifier: 100%
# [16:43:28 INFO]: Sapling Growth Modifier: 100%
# [16:43:28 INFO]: Wheat Growth Modifier: 100%
# [16:43:28 INFO]: NetherWart Growth Modifier: 100%
# [16:43:28 INFO]: Vine Growth Modifier: 100%
# [16:43:28 INFO]: Cocoa Growth Modifier: 100%
# [16:43:29 INFO]: Entity Activation Range: An 32 / Mo 32 / Mi 16
# [16:43:29 INFO]: Entity Tracking Range: Pl 48 / An 48 / Mo 48 / Mi 32 / Other 64
# [16:43:29 INFO]: Hopper Transfer: 8 Hopper Check: 1 Hopper Amount: 1
# [16:43:29 INFO]: Random Lighting Updates: false
# [16:43:29 INFO]: Structure Info Saving: true
# [16:43:29 INFO]: Custom Map Seeds:  Village: 10387312 Feature: 14357617 Monument: 10387313 Slime: 987234911
# [16:43:29 INFO]: Max TNT Explosions: 100
# [16:43:29 INFO]: Tile Max Tick Time: 50ms Entity max Tick Time: 50ms
# [16:43:29 INFO]: Item Despawn Rate: 6000
# [16:43:29 INFO]: Item Merge Radius: 2.5
# [16:43:29 INFO]: Arrow Despawn Rate: 1200
# [16:43:29 INFO]: Allow Zombie Pigmen to spawn from portal blocks: true
# [16:43:29 INFO]: View Distance: 10
# [16:43:29 INFO]: Zombie Aggressive Towards Villager: true
# [16:43:29 INFO]: Experience Merge Radius: 3.0
# [16:43:29 INFO]: Nerfing mobs spawned from spawners: false
# [16:43:29 INFO]: -------- World Settings For [world_the_end] --------
# [16:43:29 INFO]: Mob Spawn Range: 4
# [16:43:29 INFO]: Cactus Growth Modifier: 100%
# [16:43:29 INFO]: Cane Growth Modifier: 100%
# [16:43:29 INFO]: Melon Growth Modifier: 100%
# [16:43:29 INFO]: Mushroom Growth Modifier: 100%
# [16:43:29 INFO]: Pumpkin Growth Modifier: 100%
# [16:43:29 INFO]: Sapling Growth Modifier: 100%
# [16:43:29 INFO]: Wheat Growth Modifier: 100%
# [16:43:29 INFO]: NetherWart Growth Modifier: 100%
# [16:43:29 INFO]: Vine Growth Modifier: 100%
# [16:43:29 INFO]: Cocoa Growth Modifier: 100%
# [16:43:29 INFO]: Entity Activation Range: An 32 / Mo 32 / Mi 16
# [16:43:29 INFO]: Entity Tracking Range: Pl 48 / An 48 / Mo 48 / Mi 32 / Other 64
# [16:43:29 INFO]: Hopper Transfer: 8 Hopper Check: 1 Hopper Amount: 1
# [16:43:29 INFO]: Random Lighting Updates: false
# [16:43:29 INFO]: Structure Info Saving: true
# [16:43:29 INFO]: Custom Map Seeds:  Village: 10387312 Feature: 14357617 Monument: 10387313 Slime: 987234911
# [16:43:29 INFO]: Max TNT Explosions: 100
# [16:43:29 INFO]: Tile Max Tick Time: 50ms Entity max Tick Time: 50ms
# [16:43:29 INFO]: Item Despawn Rate: 6000
# [16:43:29 INFO]: Item Merge Radius: 2.5
# [16:43:29 INFO]: Arrow Despawn Rate: 1200
# [16:43:29 INFO]: Allow Zombie Pigmen to spawn from portal blocks: true
# [16:43:29 INFO]: View Distance: 10
# [16:43:29 INFO]: Zombie Aggressive Towards Villager: true
# [16:43:29 INFO]: Experience Merge Radius: 3.0
# [16:43:29 INFO]: Nerfing mobs spawned from spawners: false
# [16:43:29 INFO]: Preparing start region for level 0 (Seed: -7355063017565409559)
# [16:43:30 INFO]: Preparing spawn area: 23%
# [16:43:31 INFO]: Preparing start region for level 1 (Seed: -7779692852111467840)
# [16:43:31 INFO]: Preparing start region for level 2 (Seed: -7779692852111467840)
# [16:43:32 INFO]: [dynmap] Enabling dynmap v2.5-Dev201706100405
# [16:43:32 INFO]: [dynmap] Using Bukkit Permissions (superperms) for access control
# [16:43:32 INFO]: [dynmap] Web interface permissions only available for online users
# [16:43:33 INFO]: [dynmap] Mod Support processing completed
# [16:43:33 INFO]: [dynmap] Loaded 23 shaders.
# [16:43:33 INFO]: [dynmap] Loaded 82 perspectives.
# [16:43:33 INFO]: [dynmap] Loaded 14 lightings.
# [16:43:33 INFO]: [dynmap] Web server started on address 0.0.0.0:8123
# [16:43:33 INFO]: [dynmap] version 2.5-Dev201706100405 is enabled - core version 2.5-Dev201706100401
# [16:43:33 INFO]: [dynmap] Loaded 3 maps of world 'world'.
# [16:43:33 INFO]: [dynmap] Loaded 2 maps of world 'world_nether'.
# [16:43:33 INFO]: [dynmap] Loaded 2 maps of world 'world_the_end'.
# [16:43:33 INFO]: [dynmap] Enabled
# [16:43:33 INFO]: [MultiWorld] Enabling MultiWorld v5.2.8
# [16:43:33 INFO]: -------- World Settings For [Planets] --------
# [16:43:33 INFO]: Mob Spawn Range: 4
# [16:43:33 INFO]: Cactus Growth Modifier: 100%
# [16:43:33 INFO]: Cane Growth Modifier: 100%
# [16:43:33 INFO]: Melon Growth Modifier: 100%
# [16:43:33 INFO]: Mushroom Growth Modifier: 100%
# [16:43:33 INFO]: Pumpkin Growth Modifier: 100%
# [16:43:33 INFO]: Sapling Growth Modifier: 100%
# [16:43:33 INFO]: Wheat Growth Modifier: 100%
# [16:43:33 INFO]: NetherWart Growth Modifier: 100%
# [16:43:33 INFO]: Vine Growth Modifier: 100%
# [16:43:33 INFO]: Cocoa Growth Modifier: 100%
# [16:43:33 INFO]: Entity Activation Range: An 32 / Mo 32 / Mi 16
# [16:43:33 INFO]: Entity Tracking Range: Pl 48 / An 48 / Mo 48 / Mi 32 / Other 64
# [16:43:33 INFO]: Hopper Transfer: 8 Hopper Check: 1 Hopper Amount: 1
# [16:43:33 INFO]: Random Lighting Updates: false
# [16:43:33 INFO]: Structure Info Saving: true
# [16:43:33 INFO]: Custom Map Seeds:  Village: 10387312 Feature: 14357617 Monument: 10387313 Slime: 987234911
# [16:43:33 INFO]: Max TNT Explosions: 100
# [16:43:33 INFO]: Tile Max Tick Time: 50ms Entity max Tick Time: 50ms
# [16:43:33 INFO]: Item Despawn Rate: 6000
# [16:43:33 INFO]: Item Merge Radius: 2.5
# [16:43:33 INFO]: Arrow Despawn Rate: 1200
# [16:43:33 INFO]: Allow Zombie Pigmen to spawn from portal blocks: true
# [16:43:33 INFO]: View Distance: 10
# [16:43:33 INFO]: Zombie Aggressive Towards Villager: true
# [16:43:33 INFO]: Experience Merge Radius: 3.0
# [16:43:33 INFO]: Nerfing mobs spawned from spawners: false
# [16:43:34 INFO]: Preparing start region for level 3 (Seed: 7979255725411831799)
# [16:43:35 INFO]: Preparing spawn area for Planets, 48%
# [16:43:35 INFO]: [dynmap] Loaded 3 maps of world 'Planets'.
# [16:43:35 INFO]: -------- World Settings For [art] --------
# [16:43:35 INFO]: Mob Spawn Range: 4
# [16:43:35 INFO]: Cactus Growth Modifier: 100%
# [16:43:35 INFO]: Cane Growth Modifier: 100%
# [16:43:35 INFO]: Melon Growth Modifier: 100%
# [16:43:35 INFO]: Mushroom Growth Modifier: 100%
# [16:43:35 INFO]: Pumpkin Growth Modifier: 100%
# [16:43:35 INFO]: Sapling Growth Modifier: 100%
# [16:43:35 INFO]: Wheat Growth Modifier: 100%
# [16:43:35 INFO]: NetherWart Growth Modifier: 100%
# [16:43:35 INFO]: Vine Growth Modifier: 100%
# [16:43:35 INFO]: Cocoa Growth Modifier: 100%
# [16:43:35 INFO]: Entity Activation Range: An 32 / Mo 32 / Mi 16
# [16:43:35 INFO]: Entity Tracking Range: Pl 48 / An 48 / Mo 48 / Mi 32 / Other 64
# [16:43:35 INFO]: Hopper Transfer: 8 Hopper Check: 1 Hopper Amount: 1
# [16:43:35 INFO]: Random Lighting Updates: false
# [16:43:35 INFO]: Structure Info Saving: true
# [16:43:35 INFO]: Custom Map Seeds:  Village: 10387312 Feature: 14357617 Monument: 10387313 Slime: 987234911
# [16:43:35 INFO]: Max TNT Explosions: 100
# [16:43:35 INFO]: Tile Max Tick Time: 50ms Entity max Tick Time: 50ms
# [16:43:35 INFO]: Item Despawn Rate: 6000
# [16:43:35 INFO]: Item Merge Radius: 2.5
# [16:43:35 INFO]: Arrow Despawn Rate: 1200
# [16:43:35 INFO]: Allow Zombie Pigmen to spawn from portal blocks: true
# [16:43:35 INFO]: View Distance: 10
# [16:43:35 INFO]: Zombie Aggressive Towards Villager: true
# [16:43:35 INFO]: Experience Merge Radius: 3.0
# [16:43:35 INFO]: Nerfing mobs spawned from spawners: false
# [16:43:35 INFO]: Preparing start region for level 4 (Seed: 6382028332210659896)
# [16:43:36 INFO]: Preparing spawn area for art, 77%
# [16:43:36 INFO]: [dynmap] Loaded 3 maps of world 'art'.
# [16:43:36 INFO]: -------- World Settings For [fla] --------
# [16:43:36 INFO]: Mob Spawn Range: 4
# [16:43:36 INFO]: Cactus Growth Modifier: 100%
# [16:43:36 INFO]: Cane Growth Modifier: 100%
# [16:43:36 INFO]: Melon Growth Modifier: 100%
# [16:43:36 INFO]: Mushroom Growth Modifier: 100%
# [16:43:36 INFO]: Pumpkin Growth Modifier: 100%
# [16:43:36 INFO]: Sapling Growth Modifier: 100%
# [16:43:36 INFO]: Wheat Growth Modifier: 100%
# [16:43:36 INFO]: NetherWart Growth Modifier: 100%
# [16:43:36 INFO]: Vine Growth Modifier: 100%
# [16:43:36 INFO]: Cocoa Growth Modifier: 100%
# [16:43:36 INFO]: Entity Activation Range: An 32 / Mo 32 / Mi 16
# [16:43:36 INFO]: Entity Tracking Range: Pl 48 / An 48 / Mo 48 / Mi 32 / Other 64
# [16:43:36 INFO]: Hopper Transfer: 8 Hopper Check: 1 Hopper Amount: 1
# [16:43:36 INFO]: Random Lighting Updates: false
# [16:43:36 INFO]: Structure Info Saving: true
# [16:43:36 INFO]: Custom Map Seeds:  Village: 10387312 Feature: 14357617 Monument: 10387313 Slime: 987234911
# [16:43:36 INFO]: Max TNT Explosions: 100
# [16:43:36 INFO]: Tile Max Tick Time: 50ms Entity max Tick Time: 50ms
# [16:43:36 INFO]: Item Despawn Rate: 6000
# [16:43:36 INFO]: Item Merge Radius: 2.5
# [16:43:36 INFO]: Arrow Despawn Rate: 1200
# [16:43:36 INFO]: Allow Zombie Pigmen to spawn from portal blocks: true
# [16:43:36 INFO]: View Distance: 10
# [16:43:36 INFO]: Zombie Aggressive Towards Villager: true
# [16:43:36 INFO]: Experience Merge Radius: 3.0
# [16:43:36 INFO]: Nerfing mobs spawned from spawners: false
# [16:43:37 INFO]: Preparing start region for level 5 (Seed: -8764698127771529614)
# [16:43:38 INFO]: Preparing spawn area for fla, 97%
# [16:43:38 INFO]: [dynmap] Loaded 3 maps of world 'fla'.
# [16:43:38 INFO]: [dynmap] Loaded 5 pending tile renders for world 'fla'
# [16:43:38 INFO]: -------- World Settings For [hoele] --------
# [16:43:38 INFO]: Mob Spawn Range: 4
# [16:43:38 INFO]: Cactus Growth Modifier: 100%
# [16:43:38 INFO]: Cane Growth Modifier: 100%
# [16:43:38 INFO]: Melon Growth Modifier: 100%
# [16:43:38 INFO]: Mushroom Growth Modifier: 100%
# [16:43:38 INFO]: Pumpkin Growth Modifier: 100%
# [16:43:38 INFO]: Sapling Growth Modifier: 100%
# [16:43:38 INFO]: Wheat Growth Modifier: 100%
# [16:43:38 INFO]: NetherWart Growth Modifier: 100%
# [16:43:38 INFO]: Vine Growth Modifier: 100%
# [16:43:38 INFO]: Cocoa Growth Modifier: 100%
# [16:43:38 INFO]: Entity Activation Range: An 32 / Mo 32 / Mi 16
# [16:43:38 INFO]: Entity Tracking Range: Pl 48 / An 48 / Mo 48 / Mi 32 / Other 64
# [16:43:38 INFO]: Hopper Transfer: 8 Hopper Check: 1 Hopper Amount: 1
# [16:43:38 INFO]: Random Lighting Updates: false
# [16:43:38 INFO]: Structure Info Saving: true
# [16:43:38 INFO]: Custom Map Seeds:  Village: 10387312 Feature: 14357617 Monument: 10387313 Slime: 987234911
# [16:43:38 INFO]: Max TNT Explosions: 100
# [16:43:38 INFO]: Tile Max Tick Time: 50ms Entity max Tick Time: 50ms
# [16:43:38 INFO]: Item Despawn Rate: 6000
# [16:43:38 INFO]: Item Merge Radius: 2.5
# [16:43:38 INFO]: Arrow Despawn Rate: 1200
# [16:43:38 INFO]: Allow Zombie Pigmen to spawn from portal blocks: true
# [16:43:38 INFO]: View Distance: 10
# [16:43:38 INFO]: Zombie Aggressive Towards Villager: true
# [16:43:38 INFO]: Experience Merge Radius: 3.0
# [16:43:38 INFO]: Nerfing mobs spawned from spawners: false
# [16:43:38 INFO]: Preparing start region for level 6 (Seed: -5292477831585261431)
# [16:43:39 INFO]: Preparing spawn area for hoele, 32%
# [16:43:40 INFO]: Preparing spawn area for hoele, 73%
# [16:43:41 INFO]: [dynmap] Loaded 3 maps of world 'hoele'.
# [16:43:41 INFO]: -------- World Settings For [island] --------
# [16:43:41 INFO]: Mob Spawn Range: 4
# [16:43:41 INFO]: Cactus Growth Modifier: 100%
# [16:43:41 INFO]: Cane Growth Modifier: 100%
# [16:43:41 INFO]: Melon Growth Modifier: 100%
# [16:43:41 INFO]: Mushroom Growth Modifier: 100%
# [16:43:41 INFO]: Pumpkin Growth Modifier: 100%
# [16:43:41 INFO]: Sapling Growth Modifier: 100%
# [16:43:41 INFO]: Wheat Growth Modifier: 100%
# [16:43:41 INFO]: NetherWart Growth Modifier: 100%
# [16:43:41 INFO]: Vine Growth Modifier: 100%
# [16:43:41 INFO]: Cocoa Growth Modifier: 100%
# [16:43:41 INFO]: Entity Activation Range: An 32 / Mo 32 / Mi 16
# [16:43:41 INFO]: Entity Tracking Range: Pl 48 / An 48 / Mo 48 / Mi 32 / Other 64
# [16:43:41 INFO]: Hopper Transfer: 8 Hopper Check: 1 Hopper Amount: 1
# [16:43:41 INFO]: Random Lighting Updates: false
# [16:43:41 INFO]: Structure Info Saving: true
# [16:43:41 INFO]: Custom Map Seeds:  Village: 10387312 Feature: 14357617 Monument: 10387313 Slime: 987234911
# [16:43:41 INFO]: Max TNT Explosions: 100
# [16:43:41 INFO]: Tile Max Tick Time: 50ms Entity max Tick Time: 50ms
# [16:43:41 INFO]: Item Despawn Rate: 6000
# [16:43:41 INFO]: Item Merge Radius: 2.5
# [16:43:41 INFO]: Arrow Despawn Rate: 1200
# [16:43:41 INFO]: Allow Zombie Pigmen to spawn from portal blocks: true
# [16:43:41 INFO]: View Distance: 10
# [16:43:41 INFO]: Zombie Aggressive Towards Villager: true
# [16:43:41 INFO]: Experience Merge Radius: 3.0
# [16:43:41 INFO]: Nerfing mobs spawned from spawners: false
# [16:43:41 INFO]: Preparing start region for level 7 (Seed: -4257841979943021371)
# [16:43:42 INFO]: Preparing spawn area for island, 81%
# [16:43:42 INFO]: [dynmap] Loaded 3 maps of world 'island'.
# [16:43:42 INFO]: -------- World Settings For [solar] --------
# [16:43:42 INFO]: Mob Spawn Range: 4
# [16:43:42 INFO]: Cactus Growth Modifier: 100%
# [16:43:42 INFO]: Cane Growth Modifier: 100%
# [16:43:42 INFO]: Melon Growth Modifier: 100%
# [16:43:42 INFO]: Mushroom Growth Modifier: 100%
# [16:43:42 INFO]: Pumpkin Growth Modifier: 100%
# [16:43:42 INFO]: Sapling Growth Modifier: 100%
# [16:43:42 INFO]: Wheat Growth Modifier: 100%
# [16:43:42 INFO]: NetherWart Growth Modifier: 100%
# [16:43:42 INFO]: Vine Growth Modifier: 100%
# [16:43:42 INFO]: Cocoa Growth Modifier: 100%
# [16:43:42 INFO]: Entity Activation Range: An 32 / Mo 32 / Mi 16
# [16:43:42 INFO]: Entity Tracking Range: Pl 48 / An 48 / Mo 48 / Mi 32 / Other 64
# [16:43:42 INFO]: Hopper Transfer: 8 Hopper Check: 1 Hopper Amount: 1
# [16:43:42 INFO]: Random Lighting Updates: false
# [16:43:42 INFO]: Structure Info Saving: true
# [16:43:42 INFO]: Custom Map Seeds:  Village: 10387312 Feature: 14357617 Monument: 10387313 Slime: 987234911
# [16:43:42 INFO]: Max TNT Explosions: 100
# [16:43:42 INFO]: Tile Max Tick Time: 50ms Entity max Tick Time: 50ms
# [16:43:42 INFO]: Item Despawn Rate: 6000
# [16:43:42 INFO]: Item Merge Radius: 2.5
# [16:43:42 INFO]: Arrow Despawn Rate: 1200
# [16:43:42 INFO]: Allow Zombie Pigmen to spawn from portal blocks: true
# [16:43:42 INFO]: View Distance: 10
# [16:43:42 INFO]: Zombie Aggressive Towards Villager: true
# [16:43:42 INFO]: Experience Merge Radius: 3.0
# [16:43:42 INFO]: Nerfing mobs spawned from spawners: false
# [16:43:42 INFO]: Preparing start region for level 8 (Seed: -7965578445261035763)
# [16:43:43 INFO]: [dynmap] Loaded 3 maps of world 'solar'.
# [16:43:43 INFO]: [MultiWorld] v5.2.8 enabled.
# [16:43:43 INFO]: [WorldEdit] Enabling WorldEdit v6.1.9-SNAPSHOT;3733-52263ac
# [16:43:44 INFO]: WEPIF: Using the Bukkit Permissions API.
# [16:43:44 INFO]: [WorldEdit] Using com.sk89q.worldedit.bukkit.adapter.impl.Spigot_v1_12_R2 as the Bukkit adapter
# [16:43:44 INFO]: [Backpacks] Enabling Backpacks v0.1.3
# [16:43:44 INFO]: [Backpacks] Loading backpacks. Please wait...
# [16:43:44 INFO]: [Backpacks] 11 backpack(s) have been loaded.
# [16:43:44 INFO]: [Backpacks] Backpacks has been enabled!
# [16:43:44 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [16:43:44 INFO]: Done (16,119s)! For help, type "help" or "?"
# [16:43:44 INFO]: [dynmap] Loading default resource pack
# [16:45:43 INFO]: UUID of player TobF is 9740c893-7253-4f6d-aa96-f3c55f0373b0
# [16:45:43 INFO]: Tried to load unrecognized recipe: bukkit:53e92336-711d-428e-933a-50c370c6f319 removed now.
# [16:45:43 INFO]: Tried to load unrecognized recipe: bukkit:1f63390a-943b-4a5a-9b1e-10aed07b74b4 removed now.
# [16:45:43 INFO]: Tried to load unrecognized recipe: bukkit:53e92336-711d-428e-933a-50c370c6f319 removed now.
# [16:45:43 INFO]: Tried to load unrecognized recipe: bukkit:1f63390a-943b-4a5a-9b1e-10aed07b74b4 removed now.
# [16:45:44 INFO]: TobF[/192.168.2.210:2133] logged in with entity id 1021 at ([fla]-34.83905242157668, 98.0, 252.3584434543771)
# [16:46:15 INFO]: TobF issued server command: /stop
# [16:46:15 INFO]: [TobF: Stopping the server]
# [16:46:15 INFO]: Stopping server
# [16:46:15 INFO]: [Backpacks] Disabling Backpacks v0.1.3
# [16:46:15 INFO]: [Backpacks] Saving 11 backpack(s)...
# [16:46:15 INFO]: [Backpacks] Backpacks have been saved.
# [16:46:15 INFO]: [Backpacks] Backpacks has been disabled!
# [16:46:15 INFO]: [WorldEdit] Disabling WorldEdit v6.1.9-SNAPSHOT;3733-52263ac
# [16:46:15 INFO]: [MultiWorld] Disabling MultiWorld v5.2.8
# [16:46:15 INFO]: [MultiWorld] Disabled.
# [16:46:15 INFO]: [dynmap] Disabling dynmap v2.5-Dev201706100405
# [16:46:15 INFO]: [dynmap] Unloaded 11 components.
# [16:46:15 INFO]: [dynmap] Stopping map renderer...
# [16:46:16 INFO]: [dynmap] Saved 4 pending tile renders in world 'fla'
# [16:46:16 INFO]: [dynmap] Disabled
# [16:46:16 INFO]: Saving players
# [16:46:16 INFO]: TobF lost connection: Server closed
# [16:46:16 INFO]: TobF left the game
# [16:46:16 INFO]: Saving worlds
# [16:46:16 INFO]: Saving chunks for level 'world'/overworld
# [16:46:17 INFO]: Saving chunks for level 'world_nether'/the_nether
# [16:46:17 INFO]: Saving chunks for level 'world_the_end'/the_end
# [16:46:17 INFO]: Saving chunks for level 'Planets'/overworld
# [16:46:17 INFO]: Saving chunks for level 'art'/overworld
# [16:46:17 INFO]: Saving chunks for level 'fla'/overworld
# [16:46:17 INFO]: Saving chunks for level 'hoele'/overworld
# [16:46:17 INFO]: Saving chunks for level 'island'/overworld
# [16:46:17 INFO]: Saving chunks for level 'solar'/overworld
# >
